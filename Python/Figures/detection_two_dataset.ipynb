# %%
import matplotlib.pyplot as plt
import numpy as np
from cycler import cycler

# 设置图表风格为论文品质
plt.style.use('seaborn-v0_8-whitegrid')

# 自定义颜色循环（更适合区分）
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f']
plt.rcParams['axes.prop_cycle'] = cycler('color', colors)

# 增加默认图表大小和DPI（适合论文）
plt.rcParams['figure.dpi'] = 150
plt.rcParams['savefig.dpi'] = 300

# 增加线条宽度和标记大小
plt.rcParams['lines.linewidth'] = 1.5
plt.rcParams['lines.markersize'] = 5

# 增加字体大小
plt.rcParams['font.size'] = 14
plt.rcParams['axes.titlesize'] = 16
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['xtick.labelsize'] = 14
plt.rcParams['ytick.labelsize'] = 14
plt.rcParams['legend.fontsize'] = 14

# 数据
x = np.arange(8)

y1 = [0.908, 0.966, 0.986, 0.624, 0.937, 0.999, 0.988, 0.995]
y2 = [0.951, 0.448, 0.515, 0.068, 0.31, 0.976, 0.351, 0.832]

y3 = [0.75, 0.96, 0.98, 0.63, 0.99, 0.99, 0.98, 0.99]
y4 = [0.86, 0.44, 0.51, 0.07, 0.88, 0.96, 0.56, 0.69]

# 方法1：使用 sharex=True 参数
fig, axes = plt.subplots(1, 2, figsize=(20, 4))

# 第一个子图
axes[0].bar(x - 0.125, y1, width=0.25, hatch='/',
               edgecolor='white', label='Accuracy')
axes[0].bar(x + 0.125, y2, width=0.25, hatch='/',
               edgecolor='white', label='F1 Score')
axes[0].set_xticks(x, ['TsMon', 'HSTD', 'Diff-1', 'Chi-Squared Test', 'IQR', 'Z-Score', 'KNN', 'AE'])

axes[0].legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=2, frameon=False)

axes[0].set_ylabel('Accuracy and F1-Score', fontweight='bold')
# axes[0].legend()
# axes[0].grid(True, alpha=0.3)
# axes[0].set_xlim(0, 90)
# axes[0].set_ylim(0)
#
# # 第二个子图
axes[1].bar(x - 0.125, y3, width=0.25, hatch='/',
               edgecolor='white', label='Accuracy')
axes[1].bar(x + 0.125, y4, width=0.25, hatch='/',
               edgecolor='white', label='F1 Score')
axes[1].set_xticks(x, ['TsMon', 'HSTD', 'Diff-1', 'Chi-Squared Test', 'IQR', 'Z-Score', 'KNN', 'AE'])

# axes[1].set_ylabel('IQR')
axes[1].legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=2, frameon=False)
# axes[1].grid(True, alpha=0.3)

axes[0].text(3.5, -0.2, '(a) Performance on Anomaly_1GE', fontsize=14, fontdict={'family': 'Times New Roman'}, ha='center', fontweight='bold')
axes[1].text(3.5, -0.2, '(b) Performance on Anomaly_2GE', fontsize=14, fontdict={'family': 'Times New Roman'}, ha='center', fontweight='bold')

# 第三个子图
# axes[2].plot(x, data[10:], label='Data flow', color='#4C72B0', marker='o', linewidth=2)
# axes[2].scatter(KNN_x, KNN_y, edgecolors='#9467bd', label='KNN', s=100, facecolors='none',linewidth=1)
# axes[2].set_ylabel('KNN')
# axes[2].set_xlabel('x')  # 只在最后一个子图设置x轴标签
# axes[2].legend()
# axes[2].grid(True, alpha=0.3)

# 调整子图间距
plt.tight_layout()
plt.savefig('./two_datase_ano_acc.pdf')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from cycler import cycler

# 设置图表风格为论文品质
plt.style.use('seaborn-v0_8-whitegrid')

# 自定义颜色循环（更适合区分）
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f']

color_style = cycler(color=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f'])
plt.rcParams['axes.prop_cycle'] = cycler('color', colors)
# plt.rc('axes', prop_cycle=cycler('color', colors))

# 增加默认图表大小和DPI（适合论文）
plt.rcParams['figure.dpi'] = 150
plt.rcParams['savefig.dpi'] = 300

# 增加线条宽度和标记大小
plt.rcParams['lines.linewidth'] = 1.5
plt.rcParams['lines.markersize'] = 3

# 增加字体大小
plt.rcParams['font.size'] = 14
plt.rcParams['axes.titlesize'] = 16
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['xtick.labelsize'] = 14
plt.rcParams['ytick.labelsize'] = 14
plt.rcParams['legend.fontsize'] = 14

# 数据
a = np.load('../hadoop.npy')
b = np.load('../websearch.npy')

# cms
c = []
with open('../hadoop_cms.csv', 'r') as f:
    for line in f:
        v = line.strip()
        c.append(float(v))
d = []
with open('../websearch_cms.csv', 'r') as f:
    for line in f:
        v = line.strip()
        d.append(float(v))

# omni
e = []
with open('../hadoop_omni.csv', 'r') as f:
    for line in f:
        v = line.strip()
        e.append(float(v))
f = []
with open('../websearch_omni.csv', 'r') as fg:
    for line in fg:
        v = line.strip()
        f.append(float(v))

# wave
g = []
with open('../hadoop_wave.csv', 'r') as fg:
    for line in fg:
        v = line.strip()
        g.append(float(v))
h = []
with open('../websearch_wave.csv', 'r') as fg:
    for line in fg:
        v = line.strip()
        h.append(float(v))

data_sorted_a = np.sort(a)
data_sorted_b = np.sort(b)
data_sorted_c = np.sort(c)
data_sorted_d = np.sort(d)
data_sorted_e = np.sort(e)

data_sorted_f = np.sort(f)
data_sorted_g = np.sort(g)
data_sorted_h = np.sort(h)

# 步骤2：计算CDF的y值（百分比）
cdf_a = np.arange(1, len(data_sorted_a)+1) / len(data_sorted_a)
cdf_b = np.arange(1, len(data_sorted_b)+1) / len(data_sorted_b)

cdf_c = np.arange(1, len(data_sorted_c)+1) / len(data_sorted_c)
cdf_d = np.arange(1, len(data_sorted_d)+1) / len(data_sorted_d)

cdf_e = np.arange(1, len(data_sorted_e)+1) / len(data_sorted_e)
cdf_f = np.arange(1, len(data_sorted_f)+1) / len(data_sorted_f)

cdf_g = np.arange(1, len(data_sorted_g)+1) / len(data_sorted_g)
cdf_h = np.arange(1, len(data_sorted_h)+1) / len(data_sorted_h)

# 方法1：使用 sharex=True 参数
fig, axes = plt.subplots(2, 4, figsize=(10, 5), sharey=True, sharex=True)

# for axl in axes:
#     for ax in axl:
#         ax.set_yticks([0, 0.2, 0.4, 0.6, 0.8, 1])
axes[0][0].xaxis.set_label_position('top')
axes[0][1].xaxis.set_label_position('top')
axes[0][2].xaxis.set_label_position('top')
axes[0][3].xaxis.set_label_position('top')


# '#ff7f0e', '#2ca02c', '#d62728',
# 第一个子图
axes[0][0].plot(data_sorted_a, cdf_a, linestyle='-', markersize=3, marker='o')
axes[1][0].plot(data_sorted_b, cdf_b, linestyle='-', markersize=3, marker='o')

axes[0][0].set_xlabel("TsAnomaly", fontsize=14)
axes[0][0].set_ylabel("CDF", fontsize=14, fontweight='bold')
axes[1][0].set_ylabel("CDF", fontsize=14, fontweight='bold')

axes[0][1].plot(data_sorted_c, cdf_c, linestyle='-', markersize=3, color='#ff7f0e', marker='o')
axes[1][1].plot(data_sorted_d, cdf_d, linestyle='-', markersize=3, color='#ff7f0e', marker='o')
axes[0][1].set_xlabel("Count-Min Sketch", fontsize=14)

axes[0][2].plot(data_sorted_e, cdf_e, linestyle='-', markersize=3, color='#2ca02c', marker='o')
axes[1][2].plot(data_sorted_f, cdf_f, linestyle='-', markersize=3, color='#2ca02c', marker='o')
axes[0][2].set_xlabel("OmniWindow", fontsize=14)

axes[0][3].plot(data_sorted_g, cdf_g, linestyle='-', markersize=3, color='#990000', marker='o')
axes[1][3].plot(data_sorted_h, cdf_h, linestyle='-', markersize=3, color='#990000', marker='o')
axes[0][3].set_xlabel("WaveSketch", fontsize=14)
# axes[0][0].set_xlabel("Cosine Similarity", fontweight='bold')
# axes[0][0].set_ylabel("CDF", fontweight='bold')
fig.text(0.53, 0.51, '(a) Hadoop Datasets', ha='center', fontsize=12, fontweight='bold', family='Times New Roman')
fig.text(0.53, 0.05, 'Cosine Similarity', ha='center', fontsize=14,  fontweight='bold')
fig.text(0.53, 0.001, '(b) Websearch Datasets', ha='center', fontsize=12, fontweight='bold', family='Times New Roman')


# plt.subplots_adjust(top=0.48, hspace=0.5)

# # 第二个子图


# axes[0][1].set_xlabel("Cosine Similarity", fontweight='bold')
# axes[0][1].set_ylabel("CDF", fontweight='bold')
# axes[1].text(0.5, -0.25, '(b) Websearch', fontsize=12, fontdict={'family': 'Times New Roman'}, ha='center', fontweight='bold')



# 调整子图间距
plt.tight_layout()
plt.subplots_adjust(hspace=0.2, bottom=0.13)
plt.savefig('./two_datasets_cdf.jpg')

plt.show()

# %%
target = [2, 3, 79, 180]

raw_1 = np.load('../raw_1.npy')
tsmon_1 = np.load('../output_1.npy')

raw_2 = np.load('../raw_2.npy')
tsmon_2 = np.load('../output_2.npy')

raw_3 = np.load('../raw_3.npy')
tsmon_3 = np.load('../output_3.npy')

raw_4 = np.load('../raw_4.npy')
tsmon_4 = np.load('../output_4.npy')

raw_5 = np.load('../raw_5.npy')
tsmon_5 = np.load('../output_5.npy')

raw_6 = np.load('../raw_6.npy')
tsmon_6 = np.load('../output_6.npy')

import matplotlib.pyplot as plt
import numpy as np
from cycler import cycler

# 设置图表风格为论文品质
plt.style.use('seaborn-v0_8-whitegrid')

# 自定义颜色循环（更适合区分）
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f']

color_style = cycler(color=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f'])
plt.rcParams['axes.prop_cycle'] = cycler('color', colors)
# plt.rc('axes', prop_cycle=cycler('color', colors))

# 增加默认图表大小和DPI（适合论文）
plt.rcParams['figure.dpi'] = 150
plt.rcParams['savefig.dpi'] = 300

# 增加线条宽度和标记大小
plt.rcParams['lines.linewidth'] = 2
plt.rcParams['lines.markersize'] = 5

# 增加字体大小
plt.rcParams['font.size'] = 17
plt.rcParams['axes.titlesize'] = 17
plt.rcParams['axes.labelsize'] = 17
plt.rcParams['xtick.labelsize'] = 17
plt.rcParams['ytick.labelsize'] = 17
plt.rcParams['legend.fontsize'] = 17

# 数据
# a = np.load('../hadoop.npy')
# b = np.load('../websearch.npy')
#
# data_sorted_a = np.sort(a)
# data_sorted_b = np.sort(b)
#
# # 步骤2：计算CDF的y值（百分比）
# cdf_a = np.arange(1, len(data_sorted_a)+1) / len(data_sorted_a)
# cdf_b = np.arange(1, len(data_sorted_b)+1) / len(data_sorted_b)

# 方法1：使用 sharex=True 参数
fig, axes = plt.subplots(2, 3, figsize=(12, 6))
axes[1][0].set_xlabel('Time Slot', fontweight='bold')
axes[1][1].set_xlabel('Time Slot', fontweight='bold')
axes[1][2].set_xlabel('Time Slot', fontweight='bold')

axes[0][0].set_ylabel('Bits', fontweight='bold')
axes[1][0].set_ylabel('Bits', fontweight='bold')


# 第一个子图
axes[0][1].plot(range(5, len(tsmon_1)), tsmon_1[5:], color='#1f77b4', alpha=1, label='TsMon', linestyle='-')
axes[0][1].scatter(range(5, len(raw_1)), raw_1[5:], color='#fe6b0c', label='Raw Flows', s=12)

# axes[0][1].tick_params(labelleft=False)
#
# # 第二个子图

p = axes[1][1].plot(range(5, len(tsmon_2)), tsmon_2[5:], color='#1f77b4', alpha=1, label='TsMon', linestyle='-')
s = axes[1][1].scatter(range(5, len(raw_2)), raw_2[5:], color='#fe6b0c', label='Raw Flows', s=12)

# axes[1][1].tick_params(labelleft=False)

axes[1][2].plot(range(5, len(tsmon_3)-5), tsmon_3[5:-5], color='#1f77b4', alpha=1, label='TsMon', linestyle='-')
axes[1][2].scatter(range(5, len(raw_3)-5), raw_3[5:-5], color='#fe6b0c', label='Raw Flows', s=12)

# axes[1][0].tick_params(labelleft=False)

axes[0][2].plot(range(5, len(tsmon_4)-7), tsmon_4[6:-6], color='#1f77b4', alpha=1, label='TsMon', linestyle='-')
axes[0][2].scatter(range(5, len(raw_4)-1), raw_4[5:-1], color='#fe6b0c', label='Raw Flows', s=12)

axes[0][0].plot(range(len(tsmon_5)-1), [abs(x/100) for x in tsmon_5[:-1] ], color='#1f77b4', alpha=1, label='TsMon', linestyle='-')
axes[0][0].scatter(range(len(raw_5)), [abs(x/100) for x in raw_5[:]], color='#ff6c0e', label='Raw Flows', s=5)

axes[1][0].plot(range(len(tsmon_6)-1), [abs(x/100) for x in tsmon_6[:-1] ], color='#1f77b4', alpha=1, label='TsMon', linestyle='-')
axes[1][0].scatter(range(len(raw_6)), [abs(x/100) for x in raw_6[:]], color='#ff6c0e', label='Raw Flows', s=5)


# axes[0][0].tick_params(labelleft=False)

fig.legend([p[0], s], ['TsMon', 'Raw Flow'], loc='upper center', bbox_to_anchor=(0.5, 1.03), ncol=2, frameon=False)

# 调整子图间距
plt.tight_layout()
plt.subplots_adjust(top=0.95)
plt.savefig('./re.pdf')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from cycler import cycler

# 设置图表风格为论文品质
plt.style.use('seaborn-v0_8-whitegrid')

# 自定义颜色循环（更适合区分）
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f']

color_style = cycler(color=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f'])
plt.rcParams['axes.prop_cycle'] = cycler('color', colors)
# plt.rc('axes', prop_cycle=cycler('color', colors))

# 增加默认图表大小和DPI（适合论文）
plt.rcParams['figure.dpi'] = 150
plt.rcParams['savefig.dpi'] = 150

# 增加线条宽度和标记大小
plt.rcParams['lines.linewidth'] = 1.5
plt.rcParams['lines.markersize'] = 5

# 增加字体大小
plt.rcParams['font.size'] = 16
plt.rcParams['axes.titlesize'] = 16
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['xtick.labelsize'] = 16
plt.rcParams['ytick.labelsize'] = 16
plt.rcParams['legend.fontsize'] = 15

x = np.arange(0, 4)
y1 = [0.987, 0.986, 0.987, 0.986]
y2 = [0.934, 0.967, 0.967, 0.982]
y3 = [0.885, 0.889, 0.889, 0.891]
y4 = [0.873, 0.885, 0.885, 0.885]
y5 = [0.975, 0.984, 0.984, 0.985]
# y6 = [0.912, 0.971, 0.971, 0.989]

y7 = [0.970, 0.973, 0.970, 0.976]
y8 = [0.934, 0.967, 0.967, 0.982]
y9 = [0.885, 0.889, 0.889, 0.891]
y10 = [0.873, 0.885, 0.885, 0.885]
y11 = [0.975, 0.984, 0.984, 0.985]
# y12 = [0.912, 0.971, 0.971, 0.989]

# 方法1：使用 sharex=True 参数
fig, axes = plt.subplots(1, 2, figsize=(12, 5), sharey=True)
axes[0].set_xticks(x, ['100', '200', '300', '400'])
axes[0].set_xlim(-0.3, 3.3)
axes[0].set_ylim(0.85, 1)
axes[0].set_ylabel('Cosine Similarity', fontweight='bold')
axes[0].set_xlabel('Memory(KB)', fontweight='bold')
axes[0].text(0.5, -0.2, '(a) Hadoop', fontsize=14,
             fontdict={'family': 'Times New Roman'},
             ha='center', fontweight='bold',
             transform=axes[0].transAxes)


axes[1].set_xticks(x, ['100', '200', '300', '400'])
axes[1].set_xlim(-0.3, 3.3)
axes[1].set_ylim(0.85, 1)
axes[1].set_xlabel('Memory(KB)', fontweight='bold')
axes[1].text(1.525, -0.2, '(b) Websearch', fontsize=14,
             fontdict={'family': 'Times New Roman'},
             ha='center', fontweight='bold',
             transform=axes[0].transAxes)


# 第一个子图
line1, = axes[0].plot(x, y1, '-', label='TsMon', marker='o')
line2, = axes[0].plot(x, y2, '--', label='Count-Min Sketch', marker='h')
line3, = axes[0].plot(x, y3, '-.', label='OmniWindow', marker='v')
line4, = axes[0].plot(x, y4, ':', label='Persist-CMS', marker='^')
line5, = axes[0].plot(x, y5, ':', label='waveSketch', marker='s')
# line6, = axes[0].plot(x, y6, ':', label='Fourier', marker='*')




# # 第二个子图

line1, = axes[1].plot(x, y7, '-', label='TsMon', marker='o')
line2, = axes[1].plot(x, y8, '--', label='Count-Min Sketch', marker='h')
line3, = axes[1].plot(x, y9, '-.', label='OmniWindow', marker='v')
line4, = axes[1].plot(x, y10, ':', label='Persist-CMS', marker='^')
line5, = axes[1].plot(x, y11, ':', label='waveSketch', marker='s')
# line6, = axes[1].plot(x, y12, ':', label='Fourier', marker='*')

fig.legend([line1, line2, line3, line4, line5], ['TsMon', 'Count-Min Sketch', 'OmniWindow', 'Persist-CMS', 'waveSketch'], loc='upper center', bbox_to_anchor=(0.52, 1.03), ncol=5, frameon=False)
# 调整子图间距
# plt.subplots_adjust(top=1.5)
plt.tight_layout()

plt.savefig('./two_datasets_re.pdf')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from cycler import cycler

# 设置图表风格为论文品质
plt.style.use('seaborn-v0_8-whitegrid')

# 自定义颜色循环（更适合区分）
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f']

color_style = cycler(color=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f'])
plt.rcParams['axes.prop_cycle'] = cycler('color', colors)
# plt.rc('axes', prop_cycle=cycler('color', colors))

# 增加默认图表大小和DPI（适合论文）
plt.rcParams['figure.dpi'] = 150
plt.rcParams['savefig.dpi'] = 150

# 增加线条宽度和标记大小
plt.rcParams['lines.linewidth'] = 1.5
plt.rcParams['lines.markersize'] = 5

# 增加字体大小
plt.rcParams['font.size'] = 14
plt.rcParams['axes.titlesize'] = 16
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['xtick.labelsize'] = 14
plt.rcParams['ytick.labelsize'] = 14
plt.rcParams['legend.fontsize'] = 14

x = range(1,31)
tsmon_rx = []
tsmon_tx = []
dma_rx = []
dma_tx = []

with open('./rate.csv', 'r') as f:
    for line in f:
        # print(line)
        trx, ttx, drx, dtx = line.strip().split(',')
        trx = float(trx)
        ttx = float(ttx)
        drx = float(drx)
        dtx = float(dtx)
        tsmon_rx.append(trx)
        tsmon_tx.append(ttx)
        dma_rx.append(drx)
        dma_tx.append(dtx)
        # print(trx, ttx)



# 方法1：使用 sharex=True 参数
fig, axes = plt.subplots(1, 1, figsize=(10, 5), sharey=True)
plt.ylim(0, 100)
plt.xlabel('Time(s)', fontweight='bold')
plt.ylabel('Gbps', fontweight='bold')


# 第一个子图
line1, = axes.plot(x, tsmon_rx, '-', label='TsMon receiving rate', marker='o')
line1, = axes.plot(x, tsmon_tx, '-', label='TsMon sending rate', marker='^')
line1, = axes.plot(x, dma_rx, '--', label='DMA receiving rate', marker='o')
line1, = axes.plot(x, dma_tx, '--', label='DMA sending rate', marker='^')

# line6, = axes[0].plot(x, y6, ':', label='Fourier', marker='*')


# fig.legend([line1, line2, line3, line4, line5], ['TsMon', 'Count-Min Sketch', 'OmniWindow', 'Persist-CMS', 'waveSketch'], loc='upper center', bbox_to_anchor=(0.5, 1.02), ncol=5, frameon=False)
# 调整子图间距
# plt.subplots_adjust(top=1.5)
plt.legend()
plt.tight_layout()

plt.savefig('./throughput.pdf')

plt.show()
